# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('/Users/ranjitsah/Downloads/TensorFlow_FILES/DATA/kc_house_data.csv')

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df.corr()['price'].sort_values(ascending=True)
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df['price'].plot(kind='hist')

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price', y='sqft_living',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price', y='long',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price', y='lat',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat',hue= 'price',data=df)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='bedrooms', y='price', data=df)

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
price_one_per = df.sort_values('price',ascending=False).iloc[216:]

# %%
price_one_per
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
# ...           ...         ...        ...       ...        ...          ...
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat',data=price_one_per,edgecolor=None,alpha=0.2,palette='RdYlGn',hue='price')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='waterfront',y='price',data=df)

# %%
df['date']=pd.to_datetime(df['date'])
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)
df['day'] = df['date'].apply(lambda date: date.day)

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='month',y='price',data=df)

# %%
df.groupby('month').mean()['price'].plot()

# %%
df.drop('day',axis=1)
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900.0         3       1.00         1180
# 1      6414100192 2014-12-09  538000.0         3       2.25         2570
# 2      5631500400 2015-02-25  180000.0         2       1.00          770
# 3      2487200875 2014-12-09  604000.0         4       3.00         1960
# 4      1954400510 2015-02-18  510000.0         3       2.00         1680
# ...           ...        ...       ...       ...        ...          ...
# 21592   263000018 2014-05-21  360000.0         3       2.50         1530
# 21593  6600060120 2015-02-23  400000.0         4       2.50         2310
# 21594  1523300141 2014-06-23  402101.0         2       0.75         1020
# 21595   291310100 2015-01-16  400000.0         3       2.50         1600
# 21596  1523300157 2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# ...

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1934        1
# 1959        1
# 1951        1
# 1948        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode  \
# 0      5650     1.0           0     0  ...      1955             0    98178
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15  year  month  day
# ...

# %%
df=df.drop(['id','date','zipcode','day'],axis=1)

# %%
df.shape
# Out:
# (21597, 20)

# %%
X=df.drop('price',axis=1).values
y=df['price'].values

# %%
X.shape
# Out:
# (21597, 19)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
y_train.shape
# Out:
# (15117,)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(X_train, y_train, validation_data=(X_test,y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 0s 3ms/step - loss: 430234009600.0000 - val_loss: 418878488576.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 2ms/step - loss: 428724387840.0000 - val_loss: 413796040704.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 2ms/step - loss: 409249218560.0000 - val_loss: 369962680320.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 2ms/step - loss: 318014554112.0000 - val_loss: 228324900864.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 2ms/step - loss: 160596213760.0000 - val_loss: 104712798208.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 2ms/step - loss: 100965113856.0000 - val_loss: 95139667968.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 2ms/step - loss: 97425784832.0000 - val_loss: 93460570112.0000
# Epoch 8/400
# ...

# %%
loss_data = pd.DataFrame(model.history.history)

# %%
loss_data.plot()

# %%
prediction = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
mean_absolute_error(y_test,prediction)
# Out:
# 100714.1223687066

# %%
mean_squared_error(y_test,prediction)**0.5
# Out:
# 163114.7485073025

# %%
explained_variance_score(y_test,prediction)
# Out:
# 0.7996172815902395

# %%
plt.figure(figsize=(12,8))
plt.scatter(y_test,prediction)
plt.plot(y_test,y_test,'r')

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
single_house
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.        , 0.81818182]])

# %%
model.predict(single_house)
# Out:
# array([[278813.56]], dtype=float32)

# %%
df.head(1)['price']
# Out:
# 0    221900.0
# Name: price, dtype: float64
